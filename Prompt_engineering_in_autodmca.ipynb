# %% [markdown]
# <a href="https://colab.research.google.com/github/1FIZANOOR/1FIZANOOR/blob/main/Prompt_engineering_in_autodmca.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Fetching of data from URL

# %%
import requests
from bs4 import BeautifulSoup

# url = 'https://www.enmassenergy.com/'
# url = 'https://ecommerce.phaedrasolutions.com/'
# url = 'https://nawazsultantechdxb.com/'
# url = 'https://basatanwertech.com/'
url = 'https://www.momina.co.uk/'
def getdata(url):
    response = requests.get(url)
    return response

# Parse the HTML content of the webpage
response = getdata(url=url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find the privacy policy using BeautifulSoup
privacy_policy = None

# Search for the privacy policy link or content
for link in soup.find_all('a'):
      if 'privacy' in str(link).lower():
        privacy_policy = link.get('href')
        if url not in privacy_policy:
            print("########################### need to append it properly")
        print("*************************", privacy_policy)
        break
if url in privacy_policy:
    response = getdata(privacy_policy)
    if response.status_code == 200:
        file_html = open("demo.html", "w")
        file_html.write(response.text)
        # print(response.text)
    print(f"Privacy Policy URL: {privacy_policy}")
else:
    print("Privacy policy not found on the website.")
# Out:
# ########################### need to append it properly
# ************************* /pages/privacy-policy
# Privacy policy not found on the website.

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL you want to fetch data from
url = 'https://www.momina.co.uk/'

# Function to fetch data from a given URL
def getdata(url):
    response = requests.get(url)
    return response

# Fetch data from the specified URL
response = getdata(url=url)

# Parse the HTML content of the webpage
soup = BeautifulSoup(response.text, 'html.parser')

# Rest of your code for finding and handling privacy policy goes here...

# %%
import requests
from bs4 import BeautifulSoup

# Define the URL you want to fetch data from
url = 'https://www.momina.co.uk/'

# Function to fetch data from a given URL
def getdata(url):
    response = requests.get(url)
    return response

# Fetch data from the specified URL
response = getdata(url=url)

# Check if the response status code is 200 (OK)
if response.status_code == 200:
    print("Data has been fetched:")
    print(response.text)  # Print the fetched data
else:
    print("Failed to fetch data from the URL.")

# Parse the HTML content of the webpage
soup = BeautifulSoup(response.text, 'html.parser')

# Rest of your code for finding and handling the privacy policy goes here...
# Out:
# Data has been fetched:
# <!doctype html>
# <html class="no-js" lang="en">
# <head>
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1, shrink-to-fit=no, user-scalable=no">
#   <meta name="theme-color" content="#4d1a58">
#   <meta name="format-detection" content="telephone=no">
#   <link rel="canonical" href="https://www.momina.co.uk/">
#   <link rel="prefetch" as="document" href="https://www.momina.co.uk">
#   <link rel="dns-prefetch" href="https://cdn.shopify.com" crossorigin>
#   <link rel="preconnect" href="https://cdn.shopify.com" crossorigin>
#   <link rel="preconnect" href="https://monorail-edge.shopifysvc.com">
#   <!-- Hotjar Tracking Code for https://www.momina.co.uk
#   <script>
#     (function(h,o,t,j,a,r){
#         h.hj=h.hj||function(){(h.hj.q=h.hj.q||[]).push(arguments)};
#         h._hjSettings={hjid:1687429,hjsv:6};
#         a=o.getElementsByTagName('head')[0];
#         r=o.createElement('script');r.async=1;
# ...

# %%
from bs4 import BeautifulSoup
import requests

# List of URLs
urls = ["https://www.momina.co.uk/"]

# Go through each URL
for url in urls:
    # Make a GET request to fetch the raw HTML content
    html_content = requests.get(url).text

    # Parse the html content
    soup = BeautifulSoup(html_content, "html.parser")

    # Find the footer section by its tag or its class (this depends on the website's design)
    footer = soup.find('footer')

    # In the footer, find all 'a' tags (which represent links)
    links = footer.find_all('a')

    # Go through all links
    for link in links:
        # If the link text or the link href contains 'privacy', print it
        if 'privacy' in link.text.lower() or 'privacy' in link.get('href', '').lower():
            print(f"Privacy Policy Link in {url}: {link.get('href')}")
# Out:
# Privacy Policy Link in https://www.momina.co.uk/: /pages/privacy-policy

# %%
# !pip install openai
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 221.4/221.4 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.0/75.0 kB 4.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.3 MB/s eta 0:00:00
# ...
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %%
# !pip install --upgrade openai

# %%
from openai import OpenAI

openai = OpenAI(api_key='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')

response = openai.chat.completions.create(
  model="gpt-3.5-turbo",
  messages=[
        {"role": "system", "content": "You are a helpful assistant."},
        {"role": "user", "content": "Who won the world series in 2020?"},
    ]
)

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.momina.co.uk/"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# Find all form tags
forms = soup.find_all('form')

# Go through all forms
for form in forms:
    # Find all input tags within the current form
    inputs = form.find_all('input')

    # Go through all inputs
    for input_tag in inputs:
        # Print the 'name' attribute of each input, which is typically used as the field name
        print(input_tag.get('name'))
# Out:
# form_type
# utf8
# contact[tags]
# contact[email]
# attributes[cat_mb_items_per_row]
# attributes[cat_tb_items_per_row]
# attributes[cat_dk_items_per_row]
# attributes[auto_hide_ofsock]
# attributes[paginate_ntt4]
# attributes[limit_ntt4]
# attributes[use_bar_lmntt4]
# None
# None
# None
# None
# None
# discount
# None
# None
# form_type
# utf8
# _method
# return_to
# currency_code
# form_type
# utf8
# contact[tags]
# contact[email]

# %% [markdown]
# text-davinci-003

# %% [markdown]
# Fetch Web Page Content

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.momina.co.uk/"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# List of keywords to search for
keywords = ["privacy policy", "privacy", "policy", "dmca", "dmca policy", "copyright policy", "legal", "terms", "terms of service", "terms and conditions"]

# Find all 'a' tags (which represent links)
links = soup.find_all('a')

# Go through all links
for link in links:
    # If the link text or the link href contains any of the keywords, print it
    for keyword in keywords:
        if keyword in link.text.lower() or keyword in link.get('href', '').lower():
            print(f"{keyword.title()} Link: {link.get('href')}")
# Out:
# Policy Link: /pages/returns-policy
# Privacy Policy Link: /pages/privacy-policy
# Privacy Link: /pages/privacy-policy
# Policy Link: /pages/privacy-policy
# Terms Link: /pages/terms-conditions

# %%
from bs4 import BeautifulSoup
import requests

url = "https://www.momina.co.uk/"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

# List of keywords to search for
keywords = ["privacy policy", "privacy", "policy", "dmca", "dmca policy", "copyright policy", "legal", "terms", "terms of service", "terms and conditions"]

# Find all 'a' tags (which represent links)
links = soup.find_all('a')

# Go through all links
for link in links:
    # If the link text or the link href contains any of the keywords, print the keyword and the link
    for keyword in keywords:
        if keyword in link.text.lower() or keyword in link.get('href', '').lower():
            print(f"{keyword.title()} Link: {link.get('href')}")
# Out:
# Policy Link: /pages/returns-policy
# Privacy Policy Link: /pages/privacy-policy
# Privacy Link: /pages/privacy-policy
# Policy Link: /pages/privacy-policy
# Terms Link: /pages/terms-conditions

# %%
import requests
from bs4 import BeautifulSoup
#url ="https://www.comsats.edu.pk/"
#url = "https://www.momina.co.uk/"
url ="https://ellis.eu/news/ellis-phd-program-call-for-applications-2023"
response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')
page_content = soup.get_text()
paragraphs = soup.find_all('p')
for p in paragraphs:
    print(p.get_text())
# Out:
# * The call is closed *
# The ELLIS PhD program is a key pillar of the ELLIS initiative whose goal is to foster and educate the best talent in machine learning and related research areas by pairing outstanding students with leading academic and industrial researchers in Europe. The program also offers a variety of networking and training activities, including summer schools and workshops. Each PhD student is co-supervised by one ELLIS fellow/scholar or unit faculty and one ELLIS fellow/scholar, unit faculty or member based in different European countries, and conducts an exchange of at least 6 months with the international advisor during their degree. One of the advisors may also come from industry, in which case the student will collaborate closely with the industry partner, and spend min. 6 months conducting research at the industrial lab. A new interdisciplinary track (with co-supervision from a different discipline) will be introduced this year!
# ...

# %% [markdown]
# Prepare the Prompt

# %%
prompt = (
    #f"As a web scraper, given a website 'https://www.momina.co.uk/'.\n"
    #"1. Check if it contains an email address.\n"
    #"2. If an email address is found, return the email address.\n"
    #"3. If no email address is found, check if there is a form on the page.\n"
    #"4. If a form is detected, guess the payload that the form expects.\n"
    #"5. Additionally, try to identify the form endpoint (URL where the form data is submitted).\n"
)

# %%
prompt = (
  f"As a web scraper, Please extract privacy policy link from the following link of website: 'https://www.momina.co.uk/'.\n"
  f"As a web scraper, Please extract form page by detecting input or signin keyword link from the following link of website: 'https://www.momina.co.uk/'.\n"
  f"As a web scraper, Please extract form form page along with its endspoint by  from the following link of website: 'https://www.momina.co.uk/'.\n"
  #f"As a web scraper,you needs to give the link of payload from page form and form endpoint by  from the following link of website: 'https://www.momina.co.uk/'.\n"
         )

# %%
# prompt = (
#   f"As a web scraper, Please extract privacy policy link from the following link of website: 'https://www.comsats.edu.pk/'.\n"
#   f"As a web scraper, Please extract form page by detecting input or signin keyword link from the following link of website: 'https://www.comsats.edu.pk/'.\n"
#   f"As a web scraper, Please extract form form page along with its endspoint by  from the following link of website: 'https://www.comsats.edu.pk/'.\n"
#   f"As a web scraper,you needs to give the link of payload from page form and form endpoint by  from the following link of website: 'https://www.comsats.edu.pk/'.\n"
#          )

# %% [markdown]
# Call the OpenAI API

# %%
from openai import OpenAI

openai = OpenAI(api_key='e,nter your key')

response = openai.completions.create(
       model="text-davinci-003",
       prompt=prompt,
       max_tokens=100,
   )

# %% [markdown]
# Extract Information

# %%
print("Generated Text:")
print(response.choices[0].text.strip())
# Out:
# Generated Text:
# For the first question, the answer is: https://www.momina.co.uk/privacy
#
# For the second question, the answer is: https://www.momina.co.uk/signin
#
# For the third question, the answer is:  https://www.momina.co.uk/form. The endpoint of the form page would be www.momina.co.uk/form/submit.

# %%
from openai import OpenAI
client = OpenAI(api_key='enter your key')

response = client.chat.completions.create(
  model="gpt-3.5-turbo-1106",
  response_format={ "type": "json_object" },
  messages=[
    {"role": "system", "content": "You are a helpful assistant designed to output JSON."},
    {"role": "user", "content": "Who won the world series in 2020?"}
  ]
)
print(response.choices[0].message.content)
# Out:
# {
#   "winner": "Los Angeles Dodgers"
# }

# %%
pip install openai==0.28
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.5/76.5 kB 1.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: openai
#     Found existing installation: openai 1.3.7
#     Uninstalling openai-1.3.7:
#       Successfully uninstalled openai-1.3.7
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# ...

# %% [markdown]
# Through environment

# %%
# !pip install huggingface_hub

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
pip install transformers

# %%
from transformers import pipeline

# Set your Hugging Face API token
api_token = 'enter your key'

# Initialize the chat pipeline with the Llama-2 model
chat = pipeline("conversational", model="meta-llama/Llama-2-7b-chat-hf", device=0)  # Adjust the device as needed
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_errors.py in hf_raise_for_status(response, endpoint_name)
#     269     try:
# --> 270         response.raise_for_status()
#     271     except HTTPError as e:
#
# /usr/local/lib/python3.10/dist-packages/requests/models.py in raise_for_status(self)
#    1020         if http_error_msg:
# -> 1021             raise HTTPError(http_error_msg, response=self)
#    1022
#
# HTTPError: 401 Client Error: Unauthorized for url: https://huggingface.co/meta-llama/Llama-2-7b-chat-hf/resolve/main/config.json
#
# The above exception was the direct cause of the following exception:
#
# GatedRepoError                            Traceback (most recent call last)
# ...

# %%
# The conversation, including the system and user messages
conversation = [
    {"role": "system", "content": "You are a helpful assistant that extracts DMCA information."},
    {"role": "user", "content": f"Please extract DMCA information from the following URL: 'https://www.momina.co.uk/'."},
]

# Make an API call to Llama-2
response = chat(conversation)

# %%
# Get the assistant's reply
assistant_reply = response[0]['message']['content']

# Print the extracted DMCA information
print("DMCA Information Extracted by Llama-2:")
print(assistant_reply)

# %%
# !pip install BeautifulSoup

# %%
import requests
from bs4 import beautifulsoup
import re
import openai
url = "https://www.momina.co.uk/"
client = openai.client()

def extract_privacy_policy(url):
    response = requests.get(url)
    soup = beautifulsoup(response.content, 'html.parser')

    # find the section containing the privacy policy link or form
    privacy_section = soup.find('div', {'class': 'privacy-policy'})

    # extract the privacy policy link or form from the section
    privacy_link = privacy_section.find('a', {'href': re.compile('privacy')})
    privacy_form = privacy_section.find('form', {'action': re.compile('privacy')})

    # generate additional privacy policy links or forms using the openai api
    prompt = f"generate privacy policy links or forms based on the given html section:\n{privacy_section.prettify()}"
    response = client.chat.completions.create(
        model="gpt-3.5-turbo",
        messages=[{"role": "assistant", "content": prompt}]
    )
    generated_links = [link['href'] for link in response['choices'][0]['message']['content'].split('\n') if link['href'] and 'privacy' in link['href']]
    generated_forms = [form['action'] for form in response['choices'][0]['message']['content'].split('\n') if form['action'] and 'privacy' in form['action']]

    # combine the extracted and generated links and forms
    links = [privacy_link['href']] + generated_links
    forms = [privacy_form['action']] + generated_forms

    # remove duplicates and irrelevant items
    links = list(set(links))
    forms = list(set(forms))

    # return the final list of privacy policy links and forms
    return links, forms
